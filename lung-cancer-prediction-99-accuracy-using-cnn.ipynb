# %% [markdown]
# # Introduction
# **Author: Samanyu**<br>
# **Language: Python**<br>
# **Accelerator: None**<br>
#
# **OS: Windows 11 Home Single Language 64-bit**<br>
# **CPU: Intel Core i7-10750H @ 2.60GHz**<br>
# **RAM: 16.0GB DDR4 @ 1464MHz**<br>
# **Graphics: NVIDIA GeForce GTX 1650 (4GB)**<br>

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

import os

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report

import keras as k
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,GlobalAveragePooling2D,Dense,Dropout,BatchNormalization,Activation
from keras.callbacks import EarlyStopping,ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # Reading Image data

# %%
data=r'/kaggle/input/lung-and-colon-cancer-histopathological-images/lung_colon_image_set/lung_image_sets'
filepaths=[]
labels=[]
folds=os.listdir(data)

for fold in folds:
    foldpath=os.path.join(data,fold)
    flist=os.listdir(foldpath)
    for file in flist:
        filepath=os.path.join(foldpath,file)
        filepaths.append(filepath)
        labels.append(fold)
        
fil= pd.Series(filepaths, name='filepaths')
lab= pd.Series(labels, name='labels')
df=pd.concat([fil, lab], axis=1)

# %%
# Looking at the distribution of our image set
plt.style.use('dark_background')
plt.figure(figsize=(20,10))
sns.countplot(data=df,x='labels')
plt.show()

# %% [markdown]
# # Data Preparation

# %%
# Peefectly balanced
# Let us split the dataset
train,te=train_test_split(df,test_size=0.2,shuffle = True,random_state=20)
valid,test=train_test_split(te,test_size=0.5,shuffle = True,random_state=20)

# %%
traingen=ImageDataGenerator(rescale=1./255)
testgen=ImageDataGenerator(rescale=1./255)
validgen=ImageDataGenerator(rescale=1./255)
train=traingen.flow_from_dataframe(train,x_col= 'filepaths', y_col= 'labels', 
                                   target_size=(244,244), class_mode= 'categorical',
                                    color_mode= 'rgb', shuffle= True, batch_size=32)
test=testgen.flow_from_dataframe(test,x_col= 'filepaths', y_col= 'labels', 
                                   target_size=(244,244), class_mode= 'categorical',
                                    color_mode= 'rgb', shuffle= False, batch_size=32)
val=validgen.flow_from_dataframe(valid,x_col= 'filepaths', y_col= 'labels', 
                                   target_size=(244,244), class_mode= 'categorical',
                                    color_mode= 'rgb', shuffle= False, batch_size=32)
# Out:
# Found 12000 validated image filenames belonging to 3 classes.
# Found 1500 validated image filenames belonging to 3 classes.
# Found 1500 validated image filenames belonging to 3 classes.

# %% [markdown]
# # CNN Model

# %%
model=Sequential()

def Cnn(model):
    model.add(Conv2D(32,(3,3),input_shape=(244,244,3),padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    
    model.add(Conv2D(64,(3,3),padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D())

    model.add(Conv2D(128,(3,3),padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D())
    model.add(Dropout(0.2))

    model.add(Conv2D(128,(3,3),padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D())
    model.add(Dropout(0.2))

    return model

def dense_layers(model):

    model.add(Dense(1024))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    model.add(Dense(256))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    return model
    
model=Cnn(model)
model.add(GlobalAveragePooling2D())
model=dense_layers(model)

model.add(Dense(3, activation='softmax'))

opt = k.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)                    │ (None, 244, 244, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_7 (Activation)            │ (None, 244, 244, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_7                │ (None, 244, 244, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 244, 244, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_8 (Activation)            │ (None, 244, 244, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_8                │ (None, 244, 244, 64)        │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 122, 122, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 122, 122, 128)       │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_9 (Activation)            │ (None, 122, 122, 128)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_9                │ (None, 122, 122, 128)       │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 61, 61, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 61, 61, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 61, 61, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_10 (Activation)           │ (None, 61, 61, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_10               │ (None, 61, 61, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 30, 30, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 30, 30, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_1           │ (None, 128)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1024)                │         132,096 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_11 (Activation)           │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_11               │ (None, 1024)                │           4,096 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 512)                 │         524,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_12 (Activation)           │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_12               │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_13 (Activation)           │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_13               │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_9 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 3)                   │             771 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,038,403 (3.96 MB)
#  Trainable params: 1,034,115 (3.94 MB)
#  Non-trainable params: 4,288 (16.75 KB)

# %%
es=EarlyStopping(monitor='val_loss', patience=25, verbose=1, restore_best_weights=True)
lr=ReduceLROnPlateau(monitor='val_loss', factor=0.001, patience=10, verbose=1, min_delta=0.0001)

callbacks_list=[es,lr]

# %%
history = model.fit(
    train,
    epochs=70,
    validation_data=val,
    callbacks=callbacks_list
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 74s 163ms/step - accuracy: 0.8383 - loss: 0.4692 - val_accuracy: 0.6607 - val_loss: 0.7231 - learning_rate: 0.0010
# Epoch 2/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 61s 162ms/step - accuracy: 0.9039 - loss: 0.2585 - val_accuracy: 0.9380 - val_loss: 0.1662 - learning_rate: 0.0010
# Epoch 3/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 59s 158ms/step - accuracy: 0.9215 - loss: 0.1999 - val_accuracy: 0.8593 - val_loss: 0.3697 - learning_rate: 0.0010
# Epoch 4/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 60s 160ms/step - accuracy: 0.9317 - loss: 0.1687 - val_accuracy: 0.8953 - val_loss: 0.3432 - learning_rate: 0.0010
# Epoch 5/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 57s 152ms/step - accuracy: 0.9377 - loss: 0.1556 - val_accuracy: 0.9440 - val_loss: 0.1505 - learning_rate: 0.0010
# Epoch 6/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 59s 157ms/step - accuracy: 0.9384 - loss: 0.1575 - val_accuracy: 0.9460 - val_loss: 0.1432 - learning_rate: 0.0010
# Epoch 7/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 59s 156ms/step - accuracy: 0.9501 - loss: 0.1263 - val_accuracy: 0.8973 - val_loss: 0.2512 - learning_rate: 0.0010
# Epoch 8/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 59s 156ms/step - accuracy: 0.9540 - loss: 0.1233 - val_accuracy: 0.9453 - val_loss: 0.1333 - learning_rate: 0.0010
# Epoch 9/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 57s 152ms/step - accuracy: 0.9508 - loss: 0.1278 - val_accuracy: 0.8813 - val_loss: 0.4082 - learning_rate: 0.0010
# Epoch 10/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 59s 156ms/step - accuracy: 0.9575 - loss: 0.1130 - val_accuracy: 0.9480 - val_loss: 0.1406 - learning_rate: 0.0010
# Epoch 11/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 57s 151ms/step - accuracy: 0.9612 - loss: 0.1079 - val_accuracy: 0.9507 - val_loss: 0.1393 - learning_rate: 0.0010
# Epoch 12/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 59s 157ms/step - accuracy: 0.9643 - loss: 0.1002 - val_accuracy: 0.9193 - val_loss: 0.1978 - learning_rate: 0.0010
# Epoch 13/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 61s 162ms/step - accuracy: 0.9627 - loss: 0.0994 - val_accuracy: 0.9380 - val_loss: 0.1717 - learning_rate: 0.0010
# Epoch 14/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 58s 155ms/step - accuracy: 0.9678 - loss: 0.0816 - val_accuracy: 0.9440 - val_loss: 0.2252 - learning_rate: 0.0010
# Epoch 15/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 60s 159ms/step - accuracy: 0.9685 - loss: 0.0821 - val_accuracy: 0.9620 - val_loss: 0.1091 - learning_rate: 0.0010
# Epoch 16/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 61s 163ms/step - accuracy: 0.9741 - loss: 0.0711 - val_accuracy: 0.9580 - val_loss: 0.1189 - learning_rate: 0.0010
# Epoch 17/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 61s 162ms/step - accuracy: 0.9798 - loss: 0.0608 - val_accuracy: 0.9607 - val_loss: 0.1271 - learning_rate: 0.0010
# Epoch 18/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 59s 157ms/step - accuracy: 0.9800 - loss: 0.0567 - val_accuracy: 0.9240 - val_loss: 0.2096 - learning_rate: 0.0010
# Epoch 19/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 59s 156ms/step - accuracy: 0.9789 - loss: 0.0564 - val_accuracy: 0.9440 - val_loss: 0.1632 - learning_rate: 0.0010
# Epoch 20/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 57s 152ms/step - accuracy: 0.9794 - loss: 0.0535 - val_accuracy: 0.9780 - val_loss: 0.0510 - learning_rate: 0.0010
# Epoch 21/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 60s 159ms/step - accuracy: 0.9834 - loss: 0.0447 - val_accuracy: 0.9727 - val_loss: 0.0715 - learning_rate: 0.0010
# Epoch 22/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 58s 154ms/step - accuracy: 0.9853 - loss: 0.0431 - val_accuracy: 0.9753 - val_loss: 0.0638 - learning_rate: 0.0010
# Epoch 23/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 60s 159ms/step - accuracy: 0.9860 - loss: 0.0430 - val_accuracy: 0.9787 - val_loss: 0.0483 - learning_rate: 0.0010
# Epoch 24/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 59s 158ms/step - accuracy: 0.9829 - loss: 0.0460 - val_accuracy: 0.9533 - val_loss: 0.1511 - learning_rate: 0.0010
# Epoch 25/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 59s 158ms/step - accuracy: 0.9843 - loss: 0.0419 - val_accuracy: 0.9707 - val_loss: 0.0889 - learning_rate: 0.0010
# Epoch 26/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 59s 157ms/step - accuracy: 0.9890 - loss: 0.0334 - val_accuracy: 0.9840 - val_loss: 0.0369 - learning_rate: 0.0010
# Epoch 27/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 60s 159ms/step - accuracy: 0.9865 - loss: 0.0387 - val_accuracy: 0.9287 - val_loss: 0.2289 - learning_rate: 0.0010
# Epoch 28/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 61s 162ms/step - accuracy: 0.9905 - loss: 0.0245 - val_accuracy: 0.6600 - val_loss: 2.2739 - learning_rate: 0.0010
# Epoch 29/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 58s 154ms/step - accuracy: 0.9890 - loss: 0.0336 - val_accuracy: 0.9693 - val_loss: 0.0802 - learning_rate: 0.0010
# Epoch 30/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 59s 157ms/step - accuracy: 0.9922 - loss: 0.0211 - val_accuracy: 0.9753 - val_loss: 0.0946 - learning_rate: 0.0010
# Epoch 31/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 58s 155ms/step - accuracy: 0.9886 - loss: 0.0333 - val_accuracy: 0.9660 - val_loss: 0.0949 - learning_rate: 0.0010
# Epoch 32/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 60s 159ms/step - accuracy: 0.9917 - loss: 0.0219 - val_accuracy: 0.9473 - val_loss: 0.1688 - learning_rate: 0.0010
# Epoch 33/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 60s 160ms/step - accuracy: 0.9918 - loss: 0.0259 - val_accuracy: 0.9813 - val_loss: 0.0520 - learning_rate: 0.0010
# Epoch 34/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 60s 159ms/step - accuracy: 0.9909 - loss: 0.0228 - val_accuracy: 0.9887 - val_loss: 0.0296 - learning_rate: 0.0010
# Epoch 35/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 61s 163ms/step - accuracy: 0.9952 - loss: 0.0168 - val_accuracy: 0.9807 - val_loss: 0.0667 - learning_rate: 0.0010
# Epoch 36/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 59s 156ms/step - accuracy: 0.9920 - loss: 0.0254 - val_accuracy: 0.9540 - val_loss: 0.1959 - learning_rate: 0.0010
# Epoch 37/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 59s 157ms/step - accuracy: 0.9902 - loss: 0.0294 - val_accuracy: 0.9347 - val_loss: 0.2250 - learning_rate: 0.0010
# Epoch 38/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 62s 164ms/step - accuracy: 0.9932 - loss: 0.0228 - val_accuracy: 0.9880 - val_loss: 0.0327 - learning_rate: 0.0010
# Epoch 39/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 61s 162ms/step - accuracy: 0.9949 - loss: 0.0145 - val_accuracy: 0.9693 - val_loss: 0.0814 - learning_rate: 0.0010
# Epoch 40/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 59s 157ms/step - accuracy: 0.9929 - loss: 0.0219 - val_accuracy: 0.9280 - val_loss: 0.2418 - learning_rate: 0.0010
# Epoch 41/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 59s 156ms/step - accuracy: 0.9929 - loss: 0.0248 - val_accuracy: 0.9607 - val_loss: 0.1305 - learning_rate: 0.0010
# Epoch 42/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 64s 171ms/step - accuracy: 0.9943 - loss: 0.0215 - val_accuracy: 0.9793 - val_loss: 0.0627 - learning_rate: 0.0010
# Epoch 43/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 60s 160ms/step - accuracy: 0.9943 - loss: 0.0152 - val_accuracy: 0.9980 - val_loss: 0.0053 - learning_rate: 0.0010
# Epoch 44/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 59s 156ms/step - accuracy: 0.9952 - loss: 0.0129 - val_accuracy: 0.9793 - val_loss: 0.0667 - learning_rate: 0.0010
# Epoch 45/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 61s 161ms/step - accuracy: 0.9936 - loss: 0.0213 - val_accuracy: 0.9760 - val_loss: 0.0614 - learning_rate: 0.0010
# Epoch 46/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 58s 154ms/step - accuracy: 0.9948 - loss: 0.0167 - val_accuracy: 0.9847 - val_loss: 0.0491 - learning_rate: 0.0010
# Epoch 47/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 59s 158ms/step - accuracy: 0.9941 - loss: 0.0171 - val_accuracy: 0.9760 - val_loss: 0.0900 - learning_rate: 0.0010
# Epoch 48/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 60s 159ms/step - accuracy: 0.9966 - loss: 0.0129 - val_accuracy: 0.9520 - val_loss: 0.1242 - learning_rate: 0.0010
# Epoch 49/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 60s 159ms/step - accuracy: 0.9954 - loss: 0.0142 - val_accuracy: 0.9880 - val_loss: 0.0349 - learning_rate: 0.0010
# Epoch 50/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 58s 156ms/step - accuracy: 0.9945 - loss: 0.0157 - val_accuracy: 0.9967 - val_loss: 0.0104 - learning_rate: 0.0010
# Epoch 51/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 58s 155ms/step - accuracy: 0.9924 - loss: 0.0189 - val_accuracy: 0.9727 - val_loss: 0.0859 - learning_rate: 0.0010
# Epoch 52/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 60s 158ms/step - accuracy: 0.9965 - loss: 0.0114 - val_accuracy: 0.9967 - val_loss: 0.0081 - learning_rate: 0.0010
# Epoch 53/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9976 - loss: 0.0074
# Epoch 53: ReduceLROnPlateau reducing learning rate to 1.0000000474974512e-06.
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 59s 157ms/step - accuracy: 0.9975 - loss: 0.0074 - val_accuracy: 0.9667 - val_loss: 0.0926 - learning_rate: 0.0010
# Epoch 54/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 58s 154ms/step - accuracy: 0.9980 - loss: 0.0060 - val_accuracy: 1.0000 - val_loss: 6.4566e-04 - learning_rate: 1.0000e-06
# Epoch 55/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 60s 159ms/step - accuracy: 0.9986 - loss: 0.0068 - val_accuracy: 1.0000 - val_loss: 5.9577e-04 - learning_rate: 1.0000e-06
# Epoch 56/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 59s 156ms/step - accuracy: 0.9978 - loss: 0.0076 - val_accuracy: 1.0000 - val_loss: 6.2127e-04 - learning_rate: 1.0000e-06
# Epoch 57/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 61s 161ms/step - accuracy: 0.9977 - loss: 0.0079 - val_accuracy: 1.0000 - val_loss: 5.9100e-04 - learning_rate: 1.0000e-06
# Epoch 58/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 58s 153ms/step - accuracy: 0.9978 - loss: 0.0060 - val_accuracy: 1.0000 - val_loss: 5.8216e-04 - learning_rate: 1.0000e-06
# Epoch 59/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 58s 153ms/step - accuracy: 0.9977 - loss: 0.0079 - val_accuracy: 1.0000 - val_loss: 6.1537e-04 - learning_rate: 1.0000e-06
# Epoch 60/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 60s 161ms/step - accuracy: 0.9977 - loss: 0.0086 - val_accuracy: 1.0000 - val_loss: 5.6878e-04 - learning_rate: 1.0000e-06
# Epoch 61/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 57s 152ms/step - accuracy: 0.9989 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 5.6895e-04 - learning_rate: 1.0000e-06
# Epoch 62/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 57s 153ms/step - accuracy: 0.9969 - loss: 0.0130 - val_accuracy: 1.0000 - val_loss: 5.7284e-04 - learning_rate: 1.0000e-06
# Epoch 63/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 59s 158ms/step - accuracy: 0.9982 - loss: 0.0071 - val_accuracy: 1.0000 - val_loss: 5.7955e-04 - learning_rate: 1.0000e-06
# Epoch 64/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 60s 160ms/step - accuracy: 0.9965 - loss: 0.0113 - val_accuracy: 1.0000 - val_loss: 5.3510e-04 - learning_rate: 1.0000e-06
# Epoch 65/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 57s 153ms/step - accuracy: 0.9972 - loss: 0.0081 - val_accuracy: 1.0000 - val_loss: 5.7296e-04 - learning_rate: 1.0000e-06
# Epoch 66/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 59s 156ms/step - accuracy: 0.9977 - loss: 0.0089 - val_accuracy: 1.0000 - val_loss: 5.7344e-04 - learning_rate: 1.0000e-06
# Epoch 67/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 59s 157ms/step - accuracy: 0.9971 - loss: 0.0079 - val_accuracy: 1.0000 - val_loss: 5.4569e-04 - learning_rate: 1.0000e-06
# Epoch 68/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 60s 159ms/step - accuracy: 0.9985 - loss: 0.0062 - val_accuracy: 1.0000 - val_loss: 5.6351e-04 - learning_rate: 1.0000e-06
# Epoch 69/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 58s 155ms/step - accuracy: 0.9969 - loss: 0.0084 - val_accuracy: 1.0000 - val_loss: 5.6337e-04 - learning_rate: 1.0000e-06
# Epoch 70/70
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 60s 160ms/step - accuracy: 0.9981 - loss: 0.0069 - val_accuracy: 1.0000 - val_loss: 5.5809e-04 - learning_rate: 1.0000e-06
# Restoring model weights from the end of the best epoch: 64.

# %% [markdown]
# # Prediction

# %%
test_loss, test_accuracy = model.evaluate(test)
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 160ms/step - accuracy: 0.9999 - loss: 7.2150e-04

# %% [markdown]
# # Evaluation

# %%
pred_probs = model.predict(test)
y_pred = np.argmax(pred_probs, axis=1)
y_true = test.classes
print("Classification Report\n\n")
print(classification_report(y_true, y_pred))
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 147ms/step
# Classification Report
#
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       499
#            1       1.00      1.00      1.00       486
#            2       1.00      1.00      1.00       515
#
#     accuracy                           1.00      1500
#    macro avg       1.00      1.00      1.00      1500
# weighted avg       1.00      1.00      1.00      1500

# %%
test_accuracy = accuracy_score(y_true, y_pred)
print(f"Test Accuracy: {test_accuracy:.2f}")

cm = confusion_matrix(y_true, y_pred)
labels = list(test.class_indices.keys())

plt.figure(figsize=(12, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='viridis',
            xticklabels=labels, yticklabels=labels,
            linewidths=0.5, linecolor='black')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# Test Accuracy: 1.00

# %%
plt.figure(figsize=(12, 6))

# Plot Loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='red')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy', color='blue')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='red')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Feedback and Suggestions

# %% [markdown]
# **Kindly provide feedback ans suggestions to improve the model**<br>
#
# **Kindly Upvote if you likes this notebook or you found this helpful**
